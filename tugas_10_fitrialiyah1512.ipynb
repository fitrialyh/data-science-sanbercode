# %%
#import semua library yang kalian butuhkan disini

import json
import tweepy
from requests_oauthlib import OAuth1

# %%
#sel ini digunakan untuk membaca tokens kalian. simpan berkas token.json pada folder yang sama dengan file tugas ini

with open("token.json") as f:
  tokens = json.load(f)

bearer_token = tokens['bearer_token']
api_key = tokens['api_key']
api_key_secret = tokens['api_key_secret']
access_token = tokens['access_token']
access_token_secret = tokens['access_token_secret']

tokens.keys()
# Out:
# dict_keys(['api_key', 'api_key_secret', 'access_token', 'access_token_secret', 'bearer_token'])

# %%
#buat variabel authentikasi dan api
auth = tweepy.OAuthHandler(api_key, api_key_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
#Buatlah sebuah fungsi dengan nama user_timeline_scraper()
#fungsi tersebut memiliki input username dari user
#Fungsi ini berguna untuk mengambil 10 tweet yang berada di timeline user.
#gunakan metode Cursor untuk tugas ini
#gunakan tweet_mode --> extended

def user_timeline_scraper(username):
  max_tweets = 10
  tweets = tweepy.Cursor(api.user_timeline,id=username).items(max_tweets)
  for tweet in tweets:
    print(f'{tweet.text} \n')

# %%
username = "MataNajwa"
user_timeline_scraper(username)
# Out:
# Penangkapan ini disertai kericuhan karena beberapa massa yang pendukung Lukas Enembe menyerang Mako Brimob Kotaraja, Kota Jayapura.
#
# Ketua KPK, Firli Bahuri, bahkan pernah terbang ke Papua untuk mendatangi Lukas Enembe. Hal ini sempat menghadirkan… https://t.co/mdu0PiQca4
#
# Berbulan-bulan setelah ditetapkan sebagai tersangka kasus gratifikasi senilai Rp1 miliar, Lukas Enembe akhirnya dit… https://t.co/aQYqKdTZrX
#
# Care Bebek: Gimana Lagu Bali Yang Simple Ini Melibas Blackpink di Tren Musik 2022?
# https://t.co/4IYOThdNUn
#
# Ada sat… https://t.co/4JioTq6Wej
#
# Besok udah Senin!
#
# Biar enggak tegang, lemesin sambil karaokean dulu. Sekalian kilas balik episode Musyawarah di 20… https://t.co/Epxudr3McD
#
# Weekend ini pada liburan ke mana, Guys?
#
# “Enak ya jadi pro player, main game doang dapet duit.”
#
# Hmmm, belum tau aja. Enggak semua seindah kelihatannya. | M… https://t.co/91r25r2y1b
#
# Sebab urgensi dibentuknya Perppu Ciptaker masih dipertanyakan, masyarakat sipil pun menggugat Perppu ini ke MK.
#
# Perppu Ciptaker menuai kontroversi sejak pertama dikeluarkan 30 Desember lalu. Rilisnya Perppu Ciptaker dianggap ra… https://t.co/MUb0tHXcxc
#
# Belajar lebih banyak dari Wishnutama di episode Mata Najwa “Menyulap GWK: Di Balik Gemerlap Cultural Night” di webs… https://t.co/mRd6n4EY6z
